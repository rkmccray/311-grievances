# %%
## import pandas

import pandas as pd

# %%
## import 311 grievance data by submission method

submission_method_df = pd.read_csv("OCGS_grievances_by_submission_method.csv")
submission_method_df

# %%
## get info

submission_method_df.info
# Out:
# <bound method DataFrame.info of          Unnamed: 0  2020 2nd Q  2020 3rd Q  2020 4th Q  2021 1st Q  \
# 0     Grievance Box        1385        1342        1264        1575
# 1  Housing Services         282         235          15          62
# 2         Referrals           1           1           4           0
# 3          Walk-Ins          17           2           0           0
# 4              Mail           0           0           0           0
# 5               311        6639        6060        2961        4456
# 6            Emails         390         508         707         580
# 7             Total        8714        8148        4951        6673
#
#    2021 2nd Q  2021 3rd Q  2021 4th Q  2022 1st Q  2022 2nd Q  2022 3rd Q  \
# 0        1576        1527        1410        1224         763         592
# 1          58          39         199         309         291         122
# 2           1           0           1           1           1           0
# ...

# %%
## isolate the 311 calls row

specific_row = submission_method_df.iloc[5]
print(specific_row)
# Out:
# Unnamed: 0      311
# 2020 2nd Q     6639
# 2020 3rd Q     6060
# 2020 4th Q     2961
# 2021 1st Q     4456
# 2021 2nd Q     5949
# 2021 3rd Q     6272
# 2021 4th Q     6479
# 2022 1st Q     7603
# 2022 2nd Q     6040
# 2022 3rd Q     5787
# 2022 4th Q     6135
# 2023 1st Q     8440
# 2023 2nd Q     7696
# 2023 3rd Q     9019
# 2023 4th Q     8809
# 2024 1st Q    10505
# 2024 2nd Q     9509
# 2024 3rd Q     7132
# Name: 5, dtype: object

# %%
## import one OCGS grievance file

df1 = pd.read_csv("OCGS_data/OCGS_FY20_Q3.csv")

# %%
## call first OCGS df

df1.head()
# Out:
#   GRIEVABLE CATEGORIES  Unnamed: 1
# 0   Classification/SRG         102
# 1             Clothing          32
# 2           Commissary          83
# 3  Correspondence/Mail         189
# 4           Employment         401

# %%
## import FY20 Q2 data

df2 = pd.read_csv("OCGS_data/OCGS_FY20_Q2.csv")

# %%
## combine Q2 and Q3

pd.concat([df1, df2])
# Out:
#                      GRIEVABLE CATEGORIES  Unnamed: 1
# 0                      Classification/SRG         102
# 1                                Clothing          32
# 2                              Commissary          83
# 3                     Correspondence/Mail         189
# 4                              Employment         401
# 5                           Environmental         538
# 6                                    Food         187
# 7                          Inmate Account         206
# 8                               Jail Time          97
# 9                                 Laundry          16
# 10                            Law Library          56
# 11  Medical\r(DOC RELATED & H&H\rRELATED)        1741
# 12                          Mental Health         135
# 13                       Personal Hygiene          55
# 14                                  Phone          42
# 15                               Programs          22
# ...

# %%
## recognize grievable categories as strings

df1['GRIEVABLE CATEGORIES'].astype(str)
# Out:
# 0                        Classification/SRG
# 1                                  Clothing
# 2                                Commissary
# 3                       Correspondence/Mail
# 4                                Employment
# 5                             Environmental
# 6                                      Food
# 7                            Inmate Account
# 8                                 Jail Time
# 9                                   Laundry
# 10                              Law Library
# 11    Medical\r(DOC RELATED & H&H\rRELATED)
# 12                            Mental Health
# 13                         Personal Hygiene
# 14                                    Phone
# 15                                 Programs
# 16                                 Property
# 17                               Recreation
# 18                                 Religion
# 19                      Rules & Regulations
# 20                                   School
# ...

# %%
## recognize count of grievances as integers

df1['Unnamed: 1'].astype(int64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 ## recognize count of grievances as integers
# ----> 3 df1['Unnamed: 1'].astype(int64)
#
# NameError: name 'int64' is not defined

# %%
## import full dataframe of OCGS grievances by submission type

submission_type_df = pd.read_csv("OCGS_grievances_by_type.csv")

# %%
## call OCGS grievance submissions df

submission_type_df
# Out:
#                               Unnamed: 0  2020 2nd Q  2020 3rd Q  2020 4th Q  \
# 0                     Classification/SRG         128         102          44
# 1                               Clothing          36          32          13
# 2                             Commissary         116          83          83
# 3                    Correspondence/Mail         235         189         198
# 4                             Employment         370         401         347
# 5                          Environmental         414         538         402
# 6                                   Food         258         187         133
# 7              Person in Custody Account         267         206         143
# 8                              Jail Time          92          97          12
# 9                        Language Access           0           0           0
# 10                               Laundry          24          16          14
# ...
